# %% [markdown]
# # IRH v21.0: Observable Extraction Demo
#
# **THEORETICAL FOUNDATION**: IRH21.md §3.2
#
# This notebook demonstrates the extraction of physical observables from
# the Cosmic Fixed Point couplings.
#
# ## Contents
#
# 1. Fine-structure constant α⁻¹
# 2. Universal exponent C_H
# 3. Fermion mass hierarchy
# 4. Comparison with experimental values

# %%
import numpy as np

# Target: α⁻¹ = 137.035999084(1)
ALPHA_INV_TARGET = 137.035999084

# Universal exponent (Eq. 1.16)
C_H = 0.045935703598

print("IRH v21.0 Observable Targets:")
print(f"  α⁻¹ = {ALPHA_INV_TARGET}")
print(f"  C_H = {C_H}")
